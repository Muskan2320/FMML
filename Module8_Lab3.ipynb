# %% [markdown]
# <a href="https://colab.research.google.com/github/Muskan2320/FMML-2022-Aug/blob/main/Module8_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-04 13:36:16--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   313MB/s    in 0.2s
#
# 2023-05-04 13:36:19 (313 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22360  1603.06186v2  Many real world graphs, such as the graphs of ...  stat
# 10063  1702.01208v1  Entity resolution (ER) is the task of identify...    cs
# 11496  1603.06743v3  We introduce the localized Lasso, which is sui...  stat
# 19815   1207.4136v1  Based on a recent development in the area of e...    cs
# 37854   0902.3619v4  The starting point of this article is the ques...  stat
# ...             ...                                                ...   ...
# 951     1402.1869v2  We study the complexity of functions computabl...  stat
# 6114   1607.06450v1  Training state-of-the-art, deep neural network...  stat
# 5829    1206.6419v1  Learning multiple tasks across heterogeneous d...    cs
# 28503  1706.08801v2  We propose an algorithm to detect approximate ...    cs
# 22294  1512.01947v1  In neuroimaging data analysis, Gaussian graphi...  stat
#
#                                                    title  year  \
# 22360              The Multiscale Laplacian Graph Kernel  2016
# 10063  A Theoretical Analysis of First Heuristics of ...  2017
# 11496    Localized Lasso for High-Dimensional Regression  2016
# 19815  Convolutional Factor Graphs as Probabilistic M...  2012
# 37854  Context tree selection and linguistic rhythm r...  2009
# ...                                                  ...   ...
# 951    On the Number of Linear Regions of Deep Neural...  2014
# 6114                                 Layer Normalization  2016
# 5829   Cross-Domain Multitask Learning with Latent Pr...  2012
# 28503  Approximate Reflection Symmetry in a Point Set...  2017
# 22294  Learning population and subject-specific brain...  2015
#
#                                                 keywords
# 22360  [molecules, structure, different, character, h...
# 10063  [resolution, identifying, underlying, therefor...
# 11496  [introduce, localized, interpretable, predicti...
# 19815  [development, introduce, convolutional, probab...
# 37854  [fingerprints, brazilian, portuguese, portugue...
# ...                                                  ...
# 951    [complexity, functions, computable, feedforwar...
# 6114   [computationally, expensive, normalize, activi...
# 5829   [heterogeneous, challenging, different, genera...
# 28503  [algorithm, approximate, reflection, volumetri...
# 22294  [neuroimaging, graphical, statistical, depende...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22360    [molecules, structure, different, character, h...
# 10063    [resolution, identifying, underlying, therefor...
# 11496    [introduce, localized, interpretable, predicti...
# 19815    [development, introduce, convolutional, probab...
# 37854    [fingerprints, brazilian, portuguese, portugue...
#                                ...
# 10846    [perspective, parametric, regression, directio...
# 22860    [dimensional, tractable, parsimonious, assumpt...
# 21533    [increasing, motivated, frameworks, multitask,...
# 13041    [distribution, underlying, distribution, distr...
# 11477    [collection, instances, widespread, bioinforma...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8813 words.
# Out of those 4593 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="20ceb00b-6527-4f90-9d3b-eb144fb537ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20ceb00b-6527-4f90-9d3b-eb144fb537ef")) {                    Plotly.newPlot(                        "20ceb00b-6527-4f90-9d3b-eb144fb537ef",                        [{"x":["laplacian","introduce","computationally","projection","subgraphs","operators","structure","procedure","recursively","construction","different","hierarchy","multiscale","character","molecules","randomized","similarity","underlying","theoretical","sacrificing","representation","crowdsourcing","understanding","information","heuristic","resolution","disparity","prominent","algorithms","performances","generated","observations","heuristics","therefore","ambiguity","furthermore","experimental","participation","identifying","consuming","challenging","crowdsourced","automated","theoretic","interpretable","optimization","alternatives","outperform","simulated","localized","personalized","dimensional","guaranteed","regression","dimensionality","parameter","efficient","regularization","iterative","exclusive","predictive","diversity","empirically","specifically","functions","transformation","represented","development","flexibility","framework","independent","corresponding","structural","conventional","resulting","distributions","probability","probabilistic","variables","linearity","identical","arbitrary","convolutional","requirement","modelling","independence","graphical","summation","transform","inference","particular","multiplicative","restriction","consistency","comparing","implement","criterion","previously","according","selection","introduction","estimation","sentences","retrieval","portuguese","simulation","literature","fingerprints","automatically","conjectures","maximizer","conjectured","compatible","brazilian","superficially","statistical","contribution","retrieved","formulated","discussed","linguistic","performance","establish","properties","alleviate","considerable","simultaneously","depression","estimates","consistent","possesses","eventually","treatment","neighborhood","convergence","illustrated","deteriorates","universally","precision","increases","consumption","electrical","corporation","classifies","prediction","difficult","traditional","associated","categorize","alignment","reduction","important","consumers","improvement","unfortunately","household","clustering","reflecting","individual","representative","detection","processing","upsampling","environment","interactive","explicitly","synthetic","conditions","algorithm","experiments","generalization","positively","generalized","benchmark","parameterized","corroborate","correlated","generally","sensitivity","incorporating","providing","optimisation","straightforward","validated","revolution","experimentally","computing","backpropagation","advantage","trainable","demonstrate","mechanism","conceptual","convenience","constructing","currently","relatively","physically","implemented","computers"],"y":[17,329,85,55,5,48,349,116,8,79,744,33,4,55,8,14,142,134,159,9,366,15,157,647,52,105,10,20,575,37,157,64,28,139,13,158,371,5,63,26,279,6,105,45,27,302,29,81,63,17,20,172,36,120,51,117,397,74,69,4,57,44,80,185,221,65,78,122,34,559,128,136,61,99,171,130,169,170,143,6,17,94,394,33,59,34,57,2,77,208,300,9,9,63,77,68,45,86,92,169,27,215,84,116,2,77,123,6,166,3,1,2,12,2,1,157,64,17,40,53,79,859,46,239,16,29,117,0,66,72,5,14,28,27,134,15,3,7,79,44,21,0,2,12,248,145,201,110,11,44,89,330,2,120,43,5,153,8,110,37,361,278,7,119,43,66,133,135,817,591,115,7,78,214,14,4,30,69,25,49,94,13,33,30,3,46,156,23,88,25,566,108,15,1,39,58,59,7,89,22],"type":"bar"},{"x":["laplacian","introduce","computationally","projection","subgraphs","operators","structure","proc ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4593,), (4593, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8033333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>from</span> <span style=''>Ontology</span> <span style=''>Streams</span> <span style=''>with</span> <span style=''>Semantic</span> <span style=''>Concept</span> <span style=''>Drift</span> <br/><br/><span style=''>Data</span> <span style=''>stream</span> <span style=''>learning</span> <span style=''>has</span> <span style=''>been</span> <span style=''>largely</span> <span style=''>studied</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.41333333333333333);'>extracting</span> <span style='background-color:rgba(0, 255, 0, 0.37551020408163266);'>knowledge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>and</span> <span style=''>rapid</span> <span style=''>data</span> <span style=''>records</span> <span style=''>In</span> <span style=''>the</span> <span style=''>semantic</span> <span style=''>Web</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.35294117647058815);'>interpreted</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.9);'>ontologies</span> <span style=''>and</span> <span style=''>its</span> <span style=''>ordered</span> <span style=''>sequence</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>represented</span> <span style=''>as</span> <span style=''>an</span> <span style=''>ontology</span> <span style=''>stream</span> <span style=''>Our</span> <span style=''>work</span> <span style=''>exploits</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.9310344827586208);'>semantics</span> <span style=''>of</span> <span style=''>such</span> <span style=''>streams</span> <span style=''>to</span> <span style=''>tackle</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>concept</span> <span style=''>drift</span> <span style=''>ie</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unexpected</span> <span style=''>changes</span> <span style=''>in</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>causing</span> <span style=''>most</span> <span style=''>of</span> <span style=''>models</span> <span style=''>to</span> <span style=''>be</span> <span style=''>less</span> <span style=''>accurate</span> <span style=''>as</span> <span style=''>time</span> <span style=''>passes</span> <span style=''>To</span> <span style=''>this</span> <span style=''>end</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>revisited</span> <span style=''>(i)</span> <span style=''>semantic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>stream</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>(ii)</span> <span style=''>models</span> <span style=''>with</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.36448598130841126);'>embeddings</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>show</span> <span style=''>accurate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>with</span> <span style=''>data</span> <span style=''>from</span> <span style=''>Dublin</span> <span style=''>and</span> <span style=''>Beijing</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Correlated</span> <span style=''>random</span> <span style=''>features</span> <span style=''>for</span> <span style=''>fast</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Correlated</span> <span style=''>Nystrom</span> <span style=''>Views</span> <span style=''>(XNV)</span> <span style=''>a</span> <span style=''>fast</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>draws</span> <span style=''>on</span> <span style=''>two</span> <span style=''>main</span> <span style=''>ideas</span> <span style=''>First</span> <span style=''>it</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generates</span> <span style=''>two</span> <span style=''>views</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consisting</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inexpensive</span> <span style=''>random</span> <span style=''>features</span> <span style=''>Second</span> <span style=''>XNV</span> <span style=''>applies</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiview</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Canonical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Correlation</span> <span style=''>Analysis</span> <span style=''>(CCA)</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unlabeled</span> <span style=''>data</span> <span style=''>to</span> <span style=''>bias</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>towards</span> <span style=''>useful</span> <span style=''>features</span> <span style=''>It</span> <span style=''>has</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>if</span> <span style=''>the</span> <span style=''>views</span> <span style=''>contains</span> <span style=''>accurate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimators</span> <span style=''>CCA</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>substantially</span> <span style=''>reduce</span> <span style=''>variance</span> <span style=''>with</span> <span style=''>a</span> <span style=''>minimal</span> <span style=''>increase</span> <span style=''>in</span> <span style=''>bias</span> <span style=''>Random</span> <span style=''>views</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>justified</span> <span style=''>by</span> <span style=''>recent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>work</span> <span style=''>showing</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>with</span> <span style=''>random</span> <span style=''>features</span> <span style=''>closely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximates</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Completion</span> <span style=''>and</span> <span style=''>Related</span> <span style=''>Problems</span> <span style=''>via</span> <span style=''>Strong</span> <span style=''>Duality</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style=''>studies</span> <span style=''>the</span> <span style=''>strong</span> <span style=''>duality</span> <span style=''>of</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.380952380952381);'>factorization</span> <span style=''>problems</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>under</span> <span style=''>certain</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>and</span> <span style=''>its</span> <span style=''>dual</span> <span style=''>have</span> <span style=''>the</span> <span style=''>same</span> <span style=''>optimum</span> <span style=''>This</span> <span style=''>has</span> <span style=''>been</span> <span style=''>well</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understood</span> <span style=''>for</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>but</span> <span style=''>little</span> <span style=''>was</span> <span style=''>known</span> <span style=''>for</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analytical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>under</span> <span style=''>certain</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>solution</span> <span style=''>of</span> <span style=''>the</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.380952380952381);'>factorization</span> <span style=''>program</span> <span style=''>is</span> <span style=''>the</span> <span style=''>same</span> <span style=''>as</span> <span style=''>its</span> <span style=''>bi</span> <span style=''>dual</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>the</span> <span style=''>global</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimality</span> <span style=''>of</span> <span style=''>the</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>program</span> <span style=''>can</span> <span style=''>be</span> <span style=''>achieved</span> <span style=''>by</span> <span style=''>solving</span> <span style=''>its</span> <span style=''>bi</span> <span style=''>dual</span> <span style=''>which</span> <span style=''>is</span> <span style=''>convex</span> <span style=''>These</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>satisfied</span> <span style=''>by</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>class</span> <span style=''>of</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.380952380952381);'>factorization</span> <span style=''>problems</span> <span style=''>although</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.380952380952381);'>factorization</span> <span style=''>problems</span> <span style=''>are</span> <span style=''>hard</span> <span style=''>to< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Comparative</span> <span style=''>study</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identifying</span> <span style=''>phytoplankton</span> <span style=''>species</span> <br/><br/><span style=''>Phytoplankton</span> <span style=''>plays</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>role</span> <span style=''>in</span> <span style=''>marine</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ecosystem</span> <span style=''>It</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biological</span> <span style=''>factor</span> <span style=''>to</span> <span style=''>assess</span> <span style=''>marine</span> <span style=''>quality</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identification</span> <span style=''>of</span> <span style=''>phytoplankton</span> <span style=''>species</span> <span style=''>has</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>monitoring</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environmental</span> <span style=''>climate</span> <span style=''>changes</span> <span style=''>and</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluating</span> <span style=''>water</span> <span style=''>quality</span> <span style=''>However</span> <span style=''>phytoplankton</span> <span style=''>species</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identification</span> <span style=''>is</span> <span style=''>not</span> <span style=''>an</span> <span style=''>easy</span> <span style=''>task</span> <span style=''>owing</span> <span style=''>to</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variability</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ambiguity</span> <span style=''>due</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>thousands</span> <span style=''>of</span> <span style=''>micro</span> <span style=''>and</span> <span style=''>pico</span> <span style=''>plankton</span> <span style=''>species</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Therefore</span> <span style=''>the</span> <span style=''>aim</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>to</span> <span style=''>build</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identifying</span> <span style=''>phytoplankton</span> <span style=''>species</span> <span style=''>and</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>features</span> <span style=''>types</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>features</span> <span style=''>type</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extracted</span> <span style=''>from</span> <span style=''>raw</span> <span style=''>signals</span> <span style=''>of</span> <span style=''>phytop ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09992836676217765)
# 	automatic (0.07055873925501432)
# 	experimental (0.13287965616045846)
# 	representation (0.1310888252148997)
# 	segmentation (0.07020057306590258)
# 	architecture (0.09240687679083094)
# 	different (0.2664756446991404)
# 	detection (0.12929799426934097)
# 	recognition (0.13861031518624642)
# 	convolutional (0.14111747851002865)
#
# Some Statistics words are:
# 	stochastic (0.1339641434262948)
# 	variables (0.14043824701195218)
# 	theoretical (0.15338645418326693)
# 	algorithm (0.3944223107569721)
# 	estimation (0.18227091633466136)
# 	statistical (0.16284860557768924)
# 	distribution (0.1852589641434263)
# 	inference (0.19123505976095617)
# 	dimensional (0.18625498007968128)
# 	regression (0.1698207171314741)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="44776389-311b-4718-a6a6-4e9cdfe649e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44776389-311b-4718-a6a6-4e9cdfe649e9")) {                    Plotly.newPlot(                        "44776389-311b-4718-a6a6-4e9cdfe649e9",                        [{"x":["laplacian","introduce","computationally","projection","subgraphs","operators","structure","procedure","recursively","construction","different","hierarchy","multiscale","character","molecules","randomized","similarity","underlying","theoretical","sacrificing","representation","crowdsourcing","understanding","information","heuristic","resolution","disparity","prominent","algorithms","performances","generated","observations","heuristics","therefore","ambiguity","furthermore","experimental","participation","identifying","consuming","challenging","crowdsourced","automated","theoretic","interpretable","optimization","alternatives","outperform","simulated","localized","personalized","dimensional","guaranteed","regression","dimensionality","parameter","efficient","regularization","iterative","exclusive","predictive","diversity","empirically","specifically","functions","transformation","represented","development","flexibility","framework","independent","corresponding","structural","conventional","resulting","distributions","probability","probabilistic","variables","linearity","identical","arbitrary","convolutional","requirement","modelling","independence","graphical","summation","transform","inference","particular","multiplicative","restriction","consistency","comparing","implement","criterion","previously","according","selection","introduction","estimation","sentences","retrieval","portuguese","simulation","literature","fingerprints","automatically","conjectures","maximizer","conjectured","compatible","brazilian","superficially","statistical","contribution","retrieved","formulated","discussed","linguistic","performance","establish","properties","alleviate","considerable","simultaneously","depression","estimates","consistent","possesses","eventually","treatment","neighborhood","convergence","illustrated","deteriorates","universally","precision","increases","consumption","electrical","corporation","classifies","prediction","difficult","traditional","associated","categorize","alignment","reduction","important","consumers","improvement","unfortunately","household","clustering","reflecting","individual","representative","detection","processing","upsampling","environment","interactive","explicitly","synthetic","conditions","algorithm","experiments","generalization","positively","generalized","benchmark","parameterized","corroborate","correlated","generally","sensitivity","incorporating","providing","optimisation","straightforward","validated","revolution","experimentally","computing","backpropagation","advantage","trainable","demonstrate","mechanism","conceptual","convenience","constructing","currently","relatively","physically","implemented","computers","digitally","performed","availability","experience","recognition","admissibility","inferential","statements","distribution","potentially","posterior","approximating","methodology","quantities","observable","characteristics","reconstruction","reconstructed","compressive","discussion","outperforms","monolingual","multilingual","embedding","translation","difference","differences","embeddings","classification","especially","assimilate","sentiment","transformed","unveiling","conditioned","effective","translating","languages","separately","incorporate","architecture","efficiency","attracted","effectiveness","segmentation","engineering","interests","advantages","innovative","optimized","dynamically","considered","displaying","contextual","advertisements ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	depression
# 	electrical
# 	cheminformatics
# 	collapsed
# 	uncollapsed
# 	suspected
# 	appliances
# 	conjugacy
# 	nonconjugate
# 	layerwise
# 	differentiability
# 	regressionclassification
# 	kantorovich
# 	indefinite
# 	nonlinearly
# 	sustainability
# 	asymptotics
# 	dendrogram
# 	literatures
# 	certificate
# Some words which never appear in Statistics papers:
# 	upsampling
# 	digitally
# 	publishers
# 	syntactic
# 	referring
# 	neighbours
# 	isolating
# 	discourse
# 	syntactically
# 	connectives
# 	keystrokes
# 	treewidth
# 	skeletons
# 	additions
# 	reversals
# 	normalizes
# 	compiling
# 	superpixels
# 	oversegmentation
# 	grassmann

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0756927998031557e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.77
